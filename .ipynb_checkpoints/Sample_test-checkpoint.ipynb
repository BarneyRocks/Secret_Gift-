# %% [markdown]
# ### 傻丫头，我想帮你更加进一步的了解你的偶像呢~

# %%
cd /Users/barney/Documents/GitHub/Secret_Gift-/f1_data
# Out:
# /Users/barney/Documents/GitHub/Secret_Gift-/f1_data

# %%
import pandas as pd

# %%
driver_test = pd.read_csv("drivers.csv",sep=',', encoding='latin-1')

# %%
driver_test.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %%
driver_test.describe
# Out:
# <bound method NDFrame.describe of      driverId           driverRef  number code    forename        surname  \
# 0           1            hamilton    44.0  HAM       Lewis       Hamilton
# 1           2            heidfeld     NaN  HEI        Nick       Heidfeld
# 2           3             rosberg     6.0  ROS        Nico        Rosberg
# 3           4              alonso    14.0  ALO    Fernando         Alonso
# 4           5          kovalainen     NaN  KOV      Heikki     Kovalainen
# 5           6            nakajima     NaN  NAK      Kazuki       Nakajima
# 6           7            bourdais     NaN  BOU  SÌ©bastien       Bourdais
# 7           8           raikkonen     7.0  RAI        Kimi    RÌ_ikkÌ¦nen
# 8           9              kubica     NaN  KUB      Robert         Kubica
# 9          10               glock     NaN  GLO        Timo          Glock
# 10         11                sato     NaN  SAT      Takuma           Sato
# ...
